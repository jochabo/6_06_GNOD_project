# %% [markdown]
# # GNOD

# %% [markdown]
# Business goal:
# Check the case_study_gnod.md file.
#
# Make sure you've understood the big picture of your project:
#
# the goal of the company (Gnod),
# their current product (Gnoosic),
# their strategy, and
# how your project fits into this context.
# Re-read the business case and the e-mail from the CTO, take a look at the flowchart and create an initial Trello board with the tasks you think you'll have to accomplish.

# %% [markdown]
# # GNOD | Part 1

# %% [markdown]
# ## Lab | Web Scraping Single Page

# %% [markdown]
# Instructions - Scraping popular songs
# Your product will take a song as an input from the user and will output another song (the recommendation). In most cases, the recommended song will have to be similar to the inputted song, but the CTO thinks that if the song is on the top charts at the moment, the user will enjoy more a recommendation of a song that's also popular at the moment.
#
# You have find data on the internet about currently popular songs. Billboard maintains a weekly Top 100 of "hot" songs here: https://www.billboard.com/charts/hot-100. CHANGED: TO https://www.popvortex.com/music/charts/top-100-songs.php !
#
# It's a good place to start! Scrape the current top 100 songs and their respective artists, and put the information into a pandas dataframe.

# %% [markdown]
# ### 1. Scrape the current top 100 songs and their respective artists, and put the information into a pandas dataframe.

# %%
# 1. import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# 2. find url and store it in a variable, we have the first 100 songs on the first page!
url = "https://www.popvortex.com/music/charts/top-100-songs.php"

# %%
# 3. download html with a get request
response = requests.get(url)
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")

# %%
# 4.2. check that the html code looks like it should
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
#get first title from google chrome
soup.select('#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p > cite')
# Out:
# [<cite class="title">Flowers</cite>]

# %%
#list with all the titles
soup.select('cite.title')
# Out:
# [<cite class="title">Flowers</cite>,
#  <cite class="title">Shakira: Bzrp Music Sessions, Vol. 53</cite>,
#  <cite class="title">VIBE (feat. Jimin of BTS)</cite>,
#  <cite class="title">Unholy</cite>,
#  <cite class="title">Anti-Hero</cite>,
#  <cite class="title">Heart Like A Truck</cite>,
#  <cite class="title">Made You Look</cite>,
#  <cite class="title">Thought You Should Know</cite>,
#  <cite class="title">Son Of A Sinner</cite>,
#  <cite class="title">wait in the truck</cite>,
#  <cite class="title">Lift Me Up (From Black Panther: Wakanda Forever - Music From and Inspired By)</cite>,
#  <cite class="title">I Ain't Worried</cite>,
#  <cite class="title">Thank God</cite>,
#  <cite class="title">I'm Good (Blue)</cite>,
#  <cite class="title">Journey</cite>,
#  <cite class="title">NEED A FAVOR</cite>,
#  <cite class="title">Unstoppable</cite>,
#  <cite class="title">Fall In Love</cite>,
#  <cite class="title">This Is Our God</cite>,
# ...

# %%
#get first artist from google chrome
soup.select('#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p > em')
# Out:
# [<em class="artist">Miley Cyrus</em>]

# %%
#get artists
soup.select('em.artist')
# Out:
# [<em class="artist">Miley Cyrus</em>,
#  <em class="artist">Bizarrap &amp; Shakira</em>,
#  <em class="artist">TAEYANG</em>,
#  <em class="artist">Sam Smith &amp; Kim Petras</em>,
#  <em class="artist">Taylor Swift</em>,
#  <em class="artist">Lainey Wilson</em>,
#  <em class="artist">Meghan Trainor</em>,
#  <em class="artist">Morgan Wallen</em>,
#  <em class="artist">Jelly Roll</em>,
#  <em class="artist">HARDY &amp; Lainey Wilson</em>,
#  <em class="artist">Rihanna</em>,
#  <em class="artist">OneRepublic</em>,
#  <em class="artist">Kane Brown &amp; Katelyn Brown</em>,
#  <em class="artist">David Guetta &amp; Bebe Rexha</em>,
#  <em class="artist">Zhang Zhe Han</em>,
#  <em class="artist">Jelly Roll</em>,
#  <em class="artist">Sia</em>,
#  <em class="artist">Bailey Zimmerman</em>,
#  <em class="artist">Phil Wickham</em>,
#  <em class="artist">Zach Bryan</em>,
#  <em class="artist">Daughtry</em>,
#  <em class="artist">Morgan Wallen</em>,
#  <em class="artist">Bailey Zimmerman</em>,
# ...

# %%
#get genres
soup.select('div.chart-content.col-xs-12.col-sm-8 > ul >li >a')
# Out:
# [<a href="top-new-songs.php"><em>New Release</em></a>,
#  <a href="/music/charts/top-pop-songs.php">Pop</a>,
#  <a href="top-new-songs.php"><em>New Release</em></a>,
#  <a href="/music/charts/top-latin-songs.php">Latin</a>,
#  <a href="top-new-songs.php"><em>New Release</em></a>,
#  <a href="/music/charts/top-kpop-songs.php">K-Pop</a>,
#  <a href="/music/charts/top-pop-songs.php">Pop</a>,
#  <a href="/music/charts/top-pop-songs.php">Pop</a>,
#  <a href="/music/charts/top-country-songs.php">Country</a>,
#  <a href="/music/charts/top-pop-songs.php">Pop</a>,
#  <a href="/music/charts/top-country-songs.php">Country</a>,
#  <a href="/music/charts/top-rock-songs.php">Rock</a>,
#  <a href="/music/charts/top-country-songs.php">Country</a>,
#  <a href="/music/charts/top-pop-songs.php">Pop</a>,
#  <a href="/music/charts/top-pop-songs.php">Pop</a>,
#  <a href="/music/charts/top-country-songs.php">Country</a>,
#  <a href="/music/charts/top-dance-songs.php">Dance</a>,
# ...

# %%
#initialize empty lists
title = []
artist = []
genre = []

# define the number of iterations of our for loop
# by checking how many elements are in the retrieved result set
# (this is equivalent but more robust than just explicitly defining 250 iterations)
num_iter = len(soup.select('cite.title'))

titlelist = soup.select('cite.title')
artistlist = soup.select('em.artist')
genrelist = soup.select('div.chart-content.col-xs-12.col-sm-8 > ul >li >a')

# iterate through the result set and retrieve all the data
for i in range(num_iter):
    title.append(titlelist[i].get_text())
    artist.append(artistlist[i].get_text())
    genre.append(genrelist[i+1].get_text())

# %%
# each list becomes a column
top_100_songs = pd.DataFrame({"title":title,
                       "artist":artist,
                       "genre":genre
                      })
pd.set_option('display.max_rows', None)
top_100_songs
# Out:
#                                                 title  \
# 0                                             Flowers
# 1               Shakira: Bzrp Music Sessions, Vol. 53
# 2                           VIBE (feat. Jimin of BTS)
# 3                                              Unholy
# 4                                           Anti-Hero
# 5                                  Heart Like A Truck
# 6                                       Made You Look
# 7                             Thought You Should Know
# 8                                     Son Of A Sinner
# 9                                   wait in the truck
# 10  Lift Me Up (From Black Panther: Wakanda Foreve...
# 11                                    I Ain't Worried
# 12                                          Thank God
# 13                                    I'm Good (Blue)
# 14                                            Journey
# 15                                       NEED A FAVOR
# ...

# %%
top_100_songs.to_csv('top_100_songs.csv', index=False)

# %% [markdown]
# # GNOD | Part 2

# %% [markdown]
# The first steps you took yesterday, were to create a list of Top Songs and Artists from scraping web sites.
#
# You should have ended with your lists in a data frame containing at least Song Title and Artist.
#
# Today you are creating a recommender where the user inputs a song title and check if that song is in the list you created.   If it is,  give a different random song and artist from the list.  If it is not on the list, let the user know that you have no recommendation at this time.

# %%
song = input("Enter your value: ")
print("your song is:", song)
# Out:
# your song is: unholy

# %%
#a['Names'].str.contains('Mel').any()
top_100_songs['title'].str.lower().str.contains(str(song).lower()).any()
# Out:
# True

# %%
#code to get the index of filtered row:
top_100_songs[top_100_songs.title.str.lower().str.contains(str(song).lower())].index[0]
# Out:
# 3

# %%
#code to get the genre of filtered row:
top_100_songs[top_100_songs.title.str.lower().str.contains(str(song).lower())]['genre'].values[0]
# Out:
# 'New Release'

# %%
#sampled_songs = top_100_songs.drop(1)
#sampled_genres_songs = sampled_songs[sampled_songs.genre == genre]

# %%
if (top_100_songs['title'].str.lower().str.contains(str(song).lower()).any() == True):
    print("ok")
    index = top_100_songs[top_100_songs.title.str.lower().str.contains(str(song).lower())].index[0]
    title = top_100_songs[top_100_songs.title.str.lower().str.contains(str(song).lower())]['title'].values[0]
    genre = top_100_songs[top_100_songs.title.str.lower().str.contains(str(song).lower())]['genre'].values[0]

    print("your picked song was: ' ", title,"' the genre is:", genre)
    songs_tobe_sampled = top_100_songs.drop(index)
    songs_tobe_sampled_genre = songs_tobe_sampled[songs_tobe_sampled.genre == str(genre)]
    sampled_songs = songs_tobe_sampled_genre.sample()
    print("here is another song recommended for you:", sampled_songs['title'].values[0], "from the artist: ",sampled_songs['artist'].values[0],"with the genre", sampled_songs['genre'].values[0] ) #random sample
else:
    print("We have no recommendation for you at this time")
# Out:
# ok
# your picked song was: '  Unholy ' the genre is: New Release
# here is another song recommended for you: Sunroof from the artist:  Nicky Youre & Dazy with the genre New Release
