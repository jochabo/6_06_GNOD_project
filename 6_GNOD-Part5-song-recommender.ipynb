# %% [markdown]
# # GNOD

# %% [markdown]
# Business goal:
# Check the case_study_gnod.md file.
#
# Make sure you've understood the big picture of your project:
#
# the goal of the company (Gnod),
# their current product (Gnoosic),
# their strategy, and
# how your project fits into this context.
# Re-read the business case and the e-mail from the CTO, take a look at the flowchart and create an initial Trello board with the tasks you think you'll have to accomplish.

# %% [markdown]
# # GNOD | Part 5

# %% [markdown]
# ## Song Recommendation

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

#for plots
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#scaling numerical variables
from sklearn.preprocessing import StandardScaler

#for clustering
from sklearn import cluster, datasets
from sklearn.cluster import KMeans
import pickle

#for spotify:
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# ### Importing Scaler and KMeans-Model

# %%
#kmeans model
kmeans = pickle.load(open('kmeans_7_cluster.p', 'rb'))

#scaler
scaler = pickle.load(open('scaler.p', 'rb'))

# %% [markdown]
# ### Getting the playlists

# %%
playlist_7_clusters = pd.read_csv('playlist_7_clusters.csv')
top_100_songs = pd.read_csv('top_100_songs.csv')

# %% [markdown]
# ### Initialize Spotipy Credentials

# %%
secrets_file = open("secrets.txt","r")
# we have to make sure, that it is a "gitignore-file" so that the client-id and client-secret are not shared on github
string = secrets_file.read()
string.split('\n')
# Out:
# ['clientid: 3c2292972796423bb9d7f5b67200561d',
#  'clientsecret: 9e59e460de064a638f0c7b2900ba9788']

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()
secrets_dict
# Out:
# {'clientid': '3c2292972796423bb9d7f5b67200561d',
#  'clientsecret': '9e59e460de064a638f0c7b2900ba9788'}

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                          client_secret=secrets_dict['clientsecret']))

# %% [markdown]
# ### See the song recommender from GNOD-Part1&2

# %% [markdown]
# #### 1. Input a song

# %%
song = input("Enter your value: ")
print("your song is:", song)
# Out:
# your song is: unholy

# %% [markdown]
# #### 2. Song recommender

# %%
if (top_100_songs['title'].str.lower().str.contains(str(song).lower()).any() == True):
    print("ok")
    index = top_100_songs[top_100_songs.title.str.lower().str.contains(str(song).lower())].index[0]
    title = top_100_songs[top_100_songs.title.str.lower().str.contains(str(song).lower())]['title'].values[0]
    genre = top_100_songs[top_100_songs.title.str.lower().str.contains(str(song).lower())]['genre'].values[0]

    print("your picked song was: ' ", title,"' the genre is:", genre)
    songs_tobe_sampled = top_100_songs.drop(index)
    songs_tobe_sampled_genre = songs_tobe_sampled[songs_tobe_sampled.genre == str(genre)]
    sampled_songs = songs_tobe_sampled_genre.sample()
    print("here is another song recommended for you:", sampled_songs['title'].values[0], "from the artist: ",sampled_songs['artist'].values[0],"with the genre", sampled_songs['genre'].values[0] ) #random sample
else:
    print("We have no recommendation for you at this time")

# %% [markdown]
# ### Improving the recommender

# %% [markdown]
# 1. Input a song
# 2. Look for that song in spotify
# 3. Retrieve the audio features
# 4. Cluster these audio features
# 5. Recommend another song in the same cluster

# %% [markdown]
# #### 1. Input a song

# %%
song = input("Enter your value: ")
print("your song is:", song)
# Out:
# your song is: unholy

# %% [markdown]
# #### 2. Look for that song in spotify

# %%
results = sp.search(q="track:" + song, type="track")
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3Aunholy&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#        'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#        'id': '2wY79sveU1sp5g7SokKOiI',
#        'name': 'Sam Smith',
#        'type': 'artist',
#        'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Xt3RrJMFv5SZkCfUE8C1J'},
#        'href': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J',
#        'id': '3Xt3RrJMFv5SZkCfUE8C1J',
#        'name': 'Kim Petras',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Xt3RrJMFv5SZkCfUE8C1J'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0gX9tkL5njRax8ymWcXARi'},
#      'href': 'https://api.spotify.com/v1/albums/0gX9tkL5njRax8ymWcXARi',
#      'id': '0gX9tkL5njRax8ymWcXARi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a935e4689f15953311772cc4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a935e4689f15953311772cc4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a935e4689f15953311772cc4',
#        'width': 64}],
#      'name': 'Unholy (feat. Kim Petras)',
#      'release_date': '2022-09-22',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0gX9tkL5njRax8ymWcXARi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#       'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#       'id': '2wY79sveU1sp5g7SokKOiI',
#       'name': 'Sam Smith',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Xt3RrJMFv5SZkCfUE8C1J'},
#       'href': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J',
#       'id': '3Xt3RrJMFv5SZkCfUE8C1J',
#       'name': 'Kim Petras',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Xt3RrJMFv5SZkCfUE8C1J'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 156943,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM72205415'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3nqQXoyQOWXiESFLlDF1hG'},
#     'href': 'https://api.spotify.com/v1/tracks/3nqQXoyQOWXiESFLlDF1hG',
#     'id': '3nqQXoyQOWXiESFLlDF1hG',
#     'is_local': False,
#     'name': 'Unholy (feat. Kim Petras)',
#     'popularity': 100,
#     'preview_url': 'https://p.scdn.co/mp3-preview/32438952b8c16f0cd11c6ec82531cfcb568d5103?cid=3c2292972796423bb9d7f5b67200561d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3nqQXoyQOWXiESFLlDF1hG'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'},
#        'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs',
#        'id': '0nmQIMXWTXfhgOBdNzhGOs',
#        'name': 'Avenged Sevenfold',
#        'type': 'artist',
#        'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3qyVLEW74vRMvVxNHjwKhk'},
#      'href': 'https://api.spotify.com/v1/albums/3qyVLEW74vRMvVxNHjwKhk',
#      'id': '3qyVLEW74vRMvVxNHjwKhk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fd1f9d8bb6c1c9c2cb229837',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fd1f9d8bb6c1c9c2cb229837',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fd1f9d8bb6c1c9c2cb229837',
#        'width': 64}],
#      'name': 'Waking The Fallen',
#      'release_date': '2003-08-26',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3qyVLEW74vRMvVxNHjwKhk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nmQIMXWTXfhgOBdNzhGOs'},
#       'href': 'https://api.spotify.com/v1/artists/0nmQIMXWTXfhgOBdNzhGOs',
#       'id': '0nmQIMXWTXfhgOBdNzhGOs',
#       'name': 'Avenged Sevenfold',
#       'type': 'artist',
#       'uri': 'spotify:artist:0nmQIMXWTXfhgOBdNzhGOs'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 283826,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHR20323015'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/78XFPcFYN8YFOHjtVwnPsl'},
#     'href': 'https://api.spotify.com/v1/tracks/78XFPcFYN8YFOHjtVwnPsl',
#     'id': '78XFPcFYN8YFOHjtVwnPsl',
#     'is_local': False,
#     'name': 'Unholy Confessions',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/53bde62965683e302cb1700fc2bcd78482b9bafd?cid=3c2292972796423bb9d7f5b67200561d',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:78XFPcFYN8YFOHjtVwnPsl'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#        'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#        'id': '2wY79sveU1sp5g7SokKOiI',
#        'name': 'Sam Smith',
#        'type': 'artist',
#        'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Xt3RrJMFv5SZkCfUE8C1J'},
#        'href': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J',
#        'id': '3Xt3RrJMFv5SZkCfUE8C1J',
#        'name': 'Kim Petras',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Xt3RrJMFv5SZkCfUE8C1J'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4pnp4w9g30yLfVIAFnZMRd'},
#        'href': 'https://api.spotify.com/v1/artists/4pnp4w9g30yLfVIAFnZMRd',
#        'id': '4pnp4w9g30yLfVIAFnZMRd',
#        'name': 'ACRAZE',
#        'type': 'artist',
#        'uri': 'spotify:artist:4pnp4w9g30yLfVIAFnZMRd'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5q2WZFrJpYs53Ky2PSjeIg'},
#      'href': 'https://api.spotify.com/v1/albums/5q2WZFrJpYs53Ky2PSjeIg',
#      'id': '5q2WZFrJpYs53Ky2PSjeIg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e53dc4fc52c286b5ba68c577',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e53dc4fc52c286b5ba68c577',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e53dc4fc52c286b5ba68c577',
#        'width': 64}],
#      'name': 'Unholy (feat. Kim Petras) [ACRAZE Remix]',
#      'release_date': '2022-10-12',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:5q2WZFrJpYs53Ky2PSjeIg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#       'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#       'id': '2wY79sveU1sp5g7SokKOiI',
#       'name': 'Sam Smith',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Xt3RrJMFv5SZkCfUE8C1J'},
#       'href': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J',
#       'id': '3Xt3RrJMFv5SZkCfUE8C1J',
#       'name': 'Kim Petras',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Xt3RrJMFv5SZkCfUE8C1J'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4pnp4w9g30yLfVIAFnZMRd'},
#       'href': 'https://api.spotify.com/v1/artists/4pnp4w9g30yLfVIAFnZMRd',
#       'id': '4pnp4w9g30yLfVIAFnZMRd',
#       'name': 'ACRAZE',
#       'type': 'artist',
#       'uri': 'spotify:artist:4pnp4w9g30yLfVIAFnZMRd'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 176500,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM72207129'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Jn3wcH9TSCFMQjlWreTft'},
#     'href': 'https://api.spotify.com/v1/tracks/2Jn3wcH9TSCFMQjlWreTft',
#     'id': '2Jn3wcH9TSCFMQjlWreTft',
#     'is_local': False,
#     'name': 'Unholy (feat. Kim Petras) - ACRAZE Remix',
#     'popularity': 75,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fa659f3a9bde9781e083f4934a5f9d692ce11096?cid=3c2292972796423bb9d7f5b67200561d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2Jn3wcH9TSCFMQjlWreTft'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#        'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#        'id': '2wY79sveU1sp5g7SokKOiI',
#        'name': 'Sam Smith',
#        'type': 'artist',
#        'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Xt3RrJMFv5SZkCfUE8C1J'},
#        'href': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J',
#        'id': '3Xt3RrJMFv5SZkCfUE8C1J',
#        'name': 'Kim Petras',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Xt3RrJMFv5SZkCfUE8C1J'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6nS5roXSAGhTGr34W6n7Et'},
#        'href': 'https://api.spotify.com/v1/artists/6nS5roXSAGhTGr34W6n7Et',
#        'id': '6nS5roXSAGhTGr34W6n7Et',
#        'name': 'Disclosure',
#        'type': 'artist',
#        'uri': 'spotify:artist:6nS5roXSAGhTGr34W6n7Et'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Ta4wnFWj2Ej3JheWSdjtj'},
#      'href': 'https://api.spotify.com/v1/albums/1Ta4wnFWj2Ej3JheWSdjtj',
#      'id': '1Ta4wnFWj2Ej3JheWSdjtj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f0dfcca2b448a3b5f1717333',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f0dfcca2b448a3b5f1717333',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f0dfcca2b448a3b5f1717333',
#        'width': 64}],
#      'name': 'Unholy (feat. Kim Petras) [Disclosure Remix]',
#      'release_date': '2022-10-14',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:1Ta4wnFWj2Ej3JheWSdjtj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#       'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#       'id': '2wY79sveU1sp5g7SokKOiI',
#       'name': 'Sam Smith',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Xt3RrJMFv5SZkCfUE8C1J'},
#       'href': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J',
#       'id': '3Xt3RrJMFv5SZkCfUE8C1J',
#       'name': 'Kim Petras',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Xt3RrJMFv5SZkCfUE8C1J'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6nS5roXSAGhTGr34W6n7Et'},
#       'href': 'https://api.spotify.com/v1/artists/6nS5roXSAGhTGr34W6n7Et',
#       'id': '6nS5roXSAGhTGr34W6n7Et',
#       'name': 'Disclosure',
#       'type': 'artist',
#       'uri': 'spotify:artist:6nS5roXSAGhTGr34W6n7Et'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 234411,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM72205816'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Tl5fhF4itz5VeXHRVGIO5'},
#     'href': 'https://api.spotify.com/v1/tracks/2Tl5fhF4itz5VeXHRVGIO5',
#     'id': '2Tl5fhF4itz5VeXHRVGIO5',
#     'is_local': False,
#     'name': 'Unholy (feat. Kim Petras) - Disclosure Remix',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2174892b7c08183476a4bc55649cdcb8c20e07ee?cid=3c2292972796423bb9d7f5b67200561d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2Tl5fhF4itz5VeXHRVGIO5'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#        'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#        'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#        'name': 'Giveon',
#        'type': 'artist',
#        'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/64LkgCfNbLqjclQYCTid8L'},
#      'href': 'https://api.spotify.com/v1/albums/64LkgCfNbLqjclQYCTid8L',
#      'id': '64LkgCfNbLqjclQYCTid8L',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732739e569d6b6d0e0abc8cd9b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022739e569d6b6d0e0abc8cd9b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512739e569d6b6d0e0abc8cd9b',
#        'width': 64}],
#      'name': 'Give Or Take',
#      'release_date': '2022-06-24',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:64LkgCfNbLqjclQYCTid8L'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#       'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#       'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#       'name': 'Giveon',
#       'type': 'artist',
#       'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 200476,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM12202966'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1nTNZgKeqm4ODmIVL07nxe'},
#     'href': 'https://api.spotify.com/v1/tracks/1nTNZgKeqm4ODmIVL07nxe',
#     'id': '1nTNZgKeqm4ODmIVL07nxe',
#     'is_local': False,
#     'name': 'Unholy Matrimony',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/44e9a11291bbab4b4c7e2c6f6d6d9a64251269d3?cid=3c2292972796423bb9d7f5b67200561d',
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:1nTNZgKeqm4ODmIVL07nxe'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00YTqRClk82aMchQQpYMd5'},
#        'href': 'https://api.spotify.com/v1/artists/00YTqRClk82aMchQQpYMd5',
#        'id': '00YTqRClk82aMchQQpYMd5',
#        'name': 'Our Last Night',
#        'type': 'artist',
#        'uri': 'spotify:artist:00YTqRClk82aMchQQpYMd5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Bezp0tXu6vUeMwtMJ1G9w'},
#      'href': 'https://api.spotify.com/v1/albums/2Bezp0tXu6vUeMwtMJ1G9w',
#      'id': '2Bezp0tXu6vUeMwtMJ1G9w',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733e746b13879e7d16b14b1a29',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023e746b13879e7d16b14b1a29',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513e746b13879e7d16b14b1a29',
#        'width': 64}],
#      'name': 'Unholy',
#      'release_date': '2022-11-04',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2Bezp0tXu6vUeMwtMJ1G9w'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00YTqRClk82aMchQQpYMd5'},
#       'href': 'https://api.spotify.com/v1/artists/00YTqRClk82aMchQQpYMd5',
#       'id': '00YTqRClk82aMchQQpYMd5',
#       'name': 'Our Last Night',
#       'type': 'artist',
#       'uri': 'spotify:artist:00YTqRClk82aMchQQpYMd5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 155333,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZTAT2247364'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1QposYqMrnrYKWRUqQT1WW'},
#     'href': 'https://api.spotify.com/v1/tracks/1QposYqMrnrYKWRUqQT1WW',
#     'id': '1QposYqMrnrYKWRUqQT1WW',
#     'is_local': False,
#     'name': 'Unholy',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a0b327276fcd376ddd242726ae79d878da515eca?cid=3c2292972796423bb9d7f5b67200561d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1QposYqMrnrYKWRUqQT1WW'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5TvFfw1MgSntdU9A7yncyA'},
#        'href': 'https://api.spotify.com/v1/artists/5TvFfw1MgSntdU9A7yncyA',
#        'id': '5TvFfw1MgSntdU9A7yncyA',
#        'name': 'Dxrk ダーク',
#        'type': 'artist',
#        'uri': 'spotify:artist:5TvFfw1MgSntdU9A7yncyA'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2W6WP4pHQTFlbr2z9S4n54'},
#        'href': 'https://api.spotify.com/v1/artists/2W6WP4pHQTFlbr2z9S4n54',
#        'id': '2W6WP4pHQTFlbr2z9S4n54',
#        'name': 'Kordhell',
#        'type': 'artist',
#        'uri': 'spotify:artist:2W6WP4pHQTFlbr2z9S4n54'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6wVX7rvKQgBNS5QvRJIQ5I'},
#      'href': 'https://api.spotify.com/v1/albums/6wVX7rvKQgBNS5QvRJIQ5I',
#      'id': '6wVX7rvKQgBNS5QvRJIQ5I',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27321b8dc5b94cfeeb12db9dbcf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0221b8dc5b94cfeeb12db9dbcf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485121b8dc5b94cfeeb12db9dbcf',
#        'width': 64}],
#      'name': 'UNHOLY',
#      'release_date': '2022-05-06',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6wVX7rvKQgBNS5QvRJIQ5I'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5TvFfw1MgSntdU9A7yncyA'},
#       'href': 'https://api.spotify.com/v1/artists/5TvFfw1MgSntdU9A7yncyA',
#       'id': '5TvFfw1MgSntdU9A7yncyA',
#       'name': 'Dxrk ダーク',
#       'type': 'artist',
#       'uri': 'spotify:artist:5TvFfw1MgSntdU9A7yncyA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2W6WP4pHQTFlbr2z9S4n54'},
#       'href': 'https://api.spotify.com/v1/artists/2W6WP4pHQTFlbr2z9S4n54',
#       'id': '2W6WP4pHQTFlbr2z9S4n54',
#       'name': 'Kordhell',
#       'type': 'artist',
#       'uri': 'spotify:artist:2W6WP4pHQTFlbr2z9S4n54'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
# ...
#     'href': 'https://api.spotify.com/v1/tracks/4tANGs1j5ycSIW14UShKHh',
#     'id': '4tANGs1j5ycSIW14UShKHh',
#     'is_local': False,
#     'name': 'Unholy',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6004a8605bffbbd270dddaba8bf38db509d59e46?cid=3c2292972796423bb9d7f5b67200561d',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4tANGs1j5ycSIW14UShKHh'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#        'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#        'id': '2wY79sveU1sp5g7SokKOiI',
#        'name': 'Sam Smith',
#        'type': 'artist',
#        'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Xt3RrJMFv5SZkCfUE8C1J'},
#        'href': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J',
#        'id': '3Xt3RrJMFv5SZkCfUE8C1J',
#        'name': 'Kim Petras',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Xt3RrJMFv5SZkCfUE8C1J'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Cs0zKBU1kc0i8ypK3B9ai'},
#        'href': 'https://api.spotify.com/v1/artists/1Cs0zKBU1kc0i8ypK3B9ai',
#        'id': '1Cs0zKBU1kc0i8ypK3B9ai',
#        'name': 'David Guetta',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/54qcVnPoasyXo6U1ncvxFb'},
#      'href': 'https://api.spotify.com/v1/albums/54qcVnPoasyXo6U1ncvxFb',
#      'id': '54qcVnPoasyXo6U1ncvxFb',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730c255b138319ea2db46e11a1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020c255b138319ea2db46e11a1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510c255b138319ea2db46e11a1',
#        'width': 64}],
#      'name': 'Unholy (feat. Kim Petras) [David Guetta Acid Remix]',
#      'release_date': '2022-12-16',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:54qcVnPoasyXo6U1ncvxFb'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#       'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#       'id': '2wY79sveU1sp5g7SokKOiI',
#       'name': 'Sam Smith',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Xt3RrJMFv5SZkCfUE8C1J'},
#       'href': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J',
#       'id': '3Xt3RrJMFv5SZkCfUE8C1J',
#       'name': 'Kim Petras',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Xt3RrJMFv5SZkCfUE8C1J'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Cs0zKBU1kc0i8ypK3B9ai'},
#       'href': 'https://api.spotify.com/v1/artists/1Cs0zKBU1kc0i8ypK3B9ai',
#       'id': '1Cs0zKBU1kc0i8ypK3B9ai',
#       'name': 'David Guetta',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 170000,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM72208221'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6uZ6M4MAhDQJDmjCcKDdVf'},
#     'href': 'https://api.spotify.com/v1/tracks/6uZ6M4MAhDQJDmjCcKDdVf',
#     'id': '6uZ6M4MAhDQJDmjCcKDdVf',
#     'is_local': False,
#     'name': 'Unholy (feat. Kim Petras) - David Guetta Acid Remix',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6364c5dc0b4e9eb4172eaeb1264eccb3a3bc9212?cid=3c2292972796423bb9d7f5b67200561d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6uZ6M4MAhDQJDmjCcKDdVf'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#        'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#        'id': '2wY79sveU1sp5g7SokKOiI',
#        'name': 'Sam Smith',
#        'type': 'artist',
#        'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Xt3RrJMFv5SZkCfUE8C1J'},
#        'href': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J',
#        'id': '3Xt3RrJMFv5SZkCfUE8C1J',
#        'name': 'Kim Petras',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Xt3RrJMFv5SZkCfUE8C1J'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7I95CM75shzCjHuTzrepjM'},
#        'href': 'https://api.spotify.com/v1/artists/7I95CM75shzCjHuTzrepjM',
#        'id': '7I95CM75shzCjHuTzrepjM',
#        'name': 'Nova Twins',
#        'type': 'artist',
#        'uri': 'spotify:artist:7I95CM75shzCjHuTzrepjM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Zq6e7bJTNwtf4IcZr4YaB'},
#      'href': 'https://api.spotify.com/v1/albums/1Zq6e7bJTNwtf4IcZr4YaB',
#      'id': '1Zq6e7bJTNwtf4IcZr4YaB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27315a695ef1884395359cd54e7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0215a695ef1884395359cd54e7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485115a695ef1884395359cd54e7',
#        'width': 64}],
#      'name': 'Unholy (feat. Kim Petras) [Nova Twins Remix]',
#      'release_date': '2022-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:1Zq6e7bJTNwtf4IcZr4YaB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#       'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#       'id': '2wY79sveU1sp5g7SokKOiI',
#       'name': 'Sam Smith',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Xt3RrJMFv5SZkCfUE8C1J'},
#       'href': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J',
#       'id': '3Xt3RrJMFv5SZkCfUE8C1J',
#       'name': 'Kim Petras',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Xt3RrJMFv5SZkCfUE8C1J'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7I95CM75shzCjHuTzrepjM'},
#       'href': 'https://api.spotify.com/v1/artists/7I95CM75shzCjHuTzrepjM',
#       'id': '7I95CM75shzCjHuTzrepjM',
#       'name': 'Nova Twins',
#       'type': 'artist',
#       'uri': 'spotify:artist:7I95CM75shzCjHuTzrepjM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 177800,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM72208233'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1G2tlG3tA7uBH5izFZpaGX'},
#     'href': 'https://api.spotify.com/v1/tracks/1G2tlG3tA7uBH5izFZpaGX',
#     'id': '1G2tlG3tA7uBH5izFZpaGX',
#     'is_local': False,
#     'name': 'Unholy (feat. Kim Petras) - Nova Twins Remix',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2a34f4da87c5d52e473a4a7bf230662177edefd0?cid=3c2292972796423bb9d7f5b67200561d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1G2tlG3tA7uBH5izFZpaGX'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=track%3Aunholy&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 3995}}

# %% [markdown]
# #### 3. Retrieve the audio features

# %%
song_uri = results['tracks']['items'][0]['uri']
song_uri
# Out:
# 'spotify:track:3nqQXoyQOWXiESFLlDF1hG'

# %%
audio_features = pd.DataFrame(sp.audio_features(song_uri))
audio_features
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.714   0.472    2    -7.375     1       0.0864         0.013
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000005     0.266    0.238  131.121  audio_features
#
#                        id                                   uri  \
# 0  3nqQXoyQOWXiESFLlDF1hG  spotify:track:3nqQXoyQOWXiESFLlDF1hG
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3nqQXoyQOWXi...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3nqQ...       156943
#
#    time_signature
# 0               4

# %% [markdown]
# #### 4. Cluster these audio features

# %% [markdown]
# Prepare Data for clustering:
# 1. Drop columns
# 2. Scaling the data

# %%
audio_features = audio_features.drop(columns=['type','id','uri','track_href','analysis_url'], axis=1)
display(audio_features.shape)
audio_features.head()
# Out:
# (1, 13)
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.714   0.472    2    -7.375     1       0.0864         0.013
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000005     0.266    0.238  131.121       156943               4

# %%
audio_features_scaled = scaler.transform(audio_features)

# %%
cluster_pred = kmeans.predict(audio_features_scaled)

# %%
cluster_pred
# Out:
# array([3], dtype=int32)

# %%
cluster_pred[0]
# Out:
# 3

# %% [markdown]
# #### 5. Recommend another song in the same cluster

# %%
playlist_7_clusters.columns
# Out:
# Index(['title', 'artist', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature', 'clusters'],
#       dtype='object')

# %%
recommended_song = playlist_7_clusters[playlist_7_clusters['clusters'] == cluster_pred[0]].sample(1)
recommended_song.head()
# Out:
#                     title        artist  danceability  energy  key  loudness  \
# 6549  If I Can't Have You  Shawn Mendes         0.691   0.823  2.0    -4.197
#
#       mode  speechiness  acousticness  instrumentalness  ...  valence  \
# 6549   1.0       0.0623         0.487               0.0  ...     0.87
#
#         tempo            type                      id  \
# 6549  123.935  audio_features  2bT1PH7Cw3J9p3t7nlXCdh
#
#                                        uri  \
# 6549  spotify:track:2bT1PH7Cw3J9p3t7nlXCdh
#
#                                              track_href  \
# 6549  https://api.spotify.com/v1/tracks/2bT1PH7Cw3J9...
#
#                                            analysis_url duration_ms  \
# 6549  https://api.spotify.com/v1/audio-analysis/2bT1...    191467.0
#
#       time_signature  clusters
# 6549             4.0         3
#
# [1 rows x 21 columns]

# %%
recommended_song['title'].values[0]
# Out:
# 'Rather Be (feat. Jess Glynne)'

# %% [markdown]
# ### Song recommender - finalized: Song recommender Part 1&2 + Part5

# %%
song = input("Enter your value: ")
print("your song is:", song)

if (top_100_songs['title'].str.lower().str.contains(str(song).lower()).any() == True):
    print("ok")
    index = top_100_songs[top_100_songs.title.str.lower().str.contains(str(song).lower())].index[0]
    title = top_100_songs[top_100_songs.title.str.lower().str.contains(str(song).lower())]['title'].values[0]
    genre = top_100_songs[top_100_songs.title.str.lower().str.contains(str(song).lower())]['genre'].values[0]

    print("your picked song was: ' ", title,"' the genre is:", genre)
    songs_tobe_sampled = top_100_songs.drop(index)
    songs_tobe_sampled_genre = songs_tobe_sampled[songs_tobe_sampled.genre == str(genre)]
    sampled_songs = songs_tobe_sampled_genre.sample()
    print("here is another song recommended for you:", sampled_songs['title'].values[0], "from the artist: ",sampled_songs['artist'].values[0],"with the genre", sampled_songs['genre'].values[0] ) #random sample
else:
    #Look for that song in spotify
    results = sp.search(q="track:" + song, type="track")
    #retrieve the audio features
    song_uri = results['tracks']['items'][0]['uri']
    audio_features = pd.DataFrame(sp.audio_features(song_uri))
    #prepare data for clustering
    audio_features = audio_features.drop(columns=['type','id','uri','track_href','analysis_url'], axis=1)
    audio_features_scaled = scaler.transform(audio_features)
    #cluster with kmeans
    cluster_pred = kmeans.predict(audio_features_scaled)
    #recommend song
    recommended_song = playlist_7_clusters[playlist_7_clusters['clusters'] == cluster_pred[0]].sample(1)

    print("here is another song recommended for you:", recommended_song['title'].values[0], "from the artist: ",recommended_song['artist'].values[0])
# Out:
# your song is: adrift
# here is another song recommended for you: Why Must The Show Go On - 2003 Digital Remaster from the artist:  Phil Oakey
